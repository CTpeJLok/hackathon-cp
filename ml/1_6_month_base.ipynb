# %%
# !pip install xlrd
# Out:
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: xlrd
# Successfully installed xlrd-2.0.1

# %%
import pandas as pd

# Загрузка данных, пропуская первую строку (заголовок)
volumes = pd.read_excel('/kaggle/input/da-rzhd/transportation_volumes.xls', header=None, skiprows=1)

# Заполнение NaN пустыми строками для корректного объединения
volumes = volumes.fillna('')

# Объединение значений второй и третьей строки, чтобы создать заголовки
new_headers = volumes.iloc[0].astype(str) + ' ' + volumes.iloc[1].astype(str)

# Применение новых заголовков
volumes.columns = new_headers

# Удаление строк, использованных для создания заголовков
volumes = volumes.drop([0, 1]).reset_index(drop=True)

# Удалить лишние пробелы из названий столбцов
volumes.columns = volumes.columns.str.strip()

# Сохранение уникальных ID
unique_ids = volumes['ID'].unique()

# Проверка результата
print(volumes.head())
# Out:
#       ID Субъект федерации отп  Субъект федерации наз Код груза  \
# 0  21220     Рязанская область   Оренбургская область     39146
# 1    912     Кировская область    Саратовская область     32411
# 2    912     Кировская область        Приморский край     32411
# 3    912     Кировская область  Удмуртская Республика     32411
# 4    912     Кировская область   Оренбургская область     32411
#
#   Месяц Гр груза по опер.номен 2022/08 Провозная плата  \
# 0                       МЕТИЗЫ                       0
# 1               ЧЕРНЫЕ МЕТАЛЛЫ                       0
# 2               ЧЕРНЫЕ МЕТАЛЛЫ                  675705
# 3               ЧЕРНЫЕ МЕТАЛЛЫ                       0
# 4               ЧЕРНЫЕ МЕТАЛЛЫ                       0
#
#   2022/08 Объем перевозок(тн) 2023/10 Провозная плата  \
# 0                           0                       0
# 1                           0                       0
# 2                         203                       0
# 3                           0                       0
# 4                           0                       0
#
#   2023/10 Объем перевозок(тн) 2024/01 Провозная плата  ...  \
# 0                           0                  140356  ...
# 1                           0                       0  ...
# 2                           0                       0  ...
# 3                           0                   62576  ...
# 4                           0                       0  ...
#
#   2023/08 Провозная плата 2023/08 Объем перевозок(тн) 2023/03 Провозная плата  \
# 0                       0                           0                       0
# 1                       0                           0                       0
# 2                       0                           0                       0
# 3                  169376                         188                  113008
# 4                  155240                          62                  776200
#
#   2023/03 Объем перевозок(тн) 2024/08 Провозная плата  \
# 0                           0                       0
# 1                           0                       0
# 2                           0                 4668608
# 3                         134                       0
# 4                         343                  151120
#
#   2024/08 Объем перевозок(тн) 2022/01 Провозная плата  \
# 0                           0                       0
# 1                           0                       0
# 2                        1155                 1440050
# 3                           0                       0
# 4                          65                       0
#
#   2022/01 Объем перевозок(тн) 2023/07 Провозная плата  \
# 0                           0                       0
# 1                           0                       0
# 2                         476                       0
# 3                           0                  224378
# 4                           0                       0
#
#   2023/07 Объем перевозок(тн)
# 0                           0
# 1                           0
# 2                           0
# 3                         274
# 4                           0
#
# [5 rows x 69 columns]

# %%
# Группируем данные по 'ID' и суммируем все денежные показатели, начиная с 5-го столбца
summed_volumes = volumes.groupby('ID').sum().iloc[:, 4:]

# Создание DataFrame для удобного отображения результата
result_volumes = summed_volumes.reset_index()

# Отображение результата
print(result_volumes)
# Out:
#         ID 2022/08 Провозная плата 2022/08 Объем перевозок(тн)  \
# 0        9                       0                           0
# 1       25                 2243274                        5616
# 2       33                13666447                        4753
# 3       86                       0                           0
# 4      115                 7681607                        2970
# ..     ...                     ...                         ...
# 951  21725                       0                           0
# 952  21726                       0                           0
# 953  21727                       0                           0
# 954  21728                       0                           0
# 955  21729                       0                           0
#
#     2023/10 Провозная плата 2023/10 Объем перевозок(тн)  \
# 0                         0                           0
# 1                   2578495                        6460
# 2                  12396634                        5192
# 3                         0                           0
# 4                  11234658                        4515
# ..                      ...                         ...
# 951                       0                           0
# 952                       0                           0
# 953                       0                           0
# 954                       0                           0
# 955                       0                           0
#
#     2024/01 Провозная плата 2024/01 Объем перевозок(тн)  \
# 0                         0                           0
# 1                   1275356                        3224
# 2                  15820882                        5229
# 3                         0                           0
# 4                   7512216                        3210
# ..                      ...                         ...
# 951                       0                           0
# 952                       0                           0
# 953                       0                           0
# 954                       0                           0
# 955                       0                           0
#
#     2022/11 Провозная плата 2022/11 Объем перевозок(тн)  \
# 0                         0                           0
# 1                   2993961                        7068
# 2                  10640937                        4325
# 3                         0                           0
# 4                   6500568                        3363
# ..                      ...                         ...
# 951                       0                           0
# 952                       0                           0
# 953                       0                           0
# 954                       0                           0
# 955                       0                           0
#
#     2022/10 Провозная плата  ... 2023/08 Провозная плата  \
# 0                         0  ...                       0
# 1                   3508112  ...                 2513860
# 2                   9133177  ...                16869383
# 3                    109251  ...                       0
# 4                  10691266  ...                21335734
# ..                      ...  ...                     ...
# 951                       0  ...                       0
# 952                       0  ...                       0
# 953                       0  ...                       0
# 954                       0  ...                       0
# 955                       0  ...                       0
#
#     2023/08 Объем перевозок(тн) 2023/03 Провозная плата  \
# 0                             0                       0
# 1                          5659                 3462925
# 2                          5339                22965212
# 3                             0                       0
# 4                          8437                 9411578
# ..                          ...                     ...
# 951                           0                       0
# 952                           0                       0
# 953                           0                       0
# 954                           0                       0
# 955                           0                       0
#
#     2023/03 Объем перевозок(тн) 2024/08 Провозная плата  \
# 0                             0                  168141
# 1                          6997                 3967481
# 2                          6488                20752565
# 3                             0                       0
# 4                          4435                14573736
# ..                          ...                     ...
# 951                           0                   15100
# 952                           0                       0
# 953                           0                       0
# 954                           0                       0
# 955                           0                       0
#
#     2024/08 Объем перевозок(тн) 2022/01 Провозная плата  \
# 0                            50                       0
# 1                          8015                 1833430
# 2                          5329                 8391136
# 3                             0                       0
# 4                          4677                 5091833
# ..                          ...                     ...
# 951                           6                       0
# 952                           0                       0
# 953                           0                       0
# 954                           0                       0
# 955                           0                       0
#
#     2022/01 Объем перевозок(тн) 2023/07 Провозная плата  \
# 0                             0                  166748
# 1                          4695                 2413016
# 2                          3760                23232439
# 3                             0                       0
# 4                          4079                15141323
# ..                          ...                     ...
# 951                           0                       0
# 952                           0                       0
# 953                           0                       0
# 954                           0                       0
# 955                           0                       0
#
#     2023/07 Объем перевозок(тн)
# 0                            55
# 1                          5732
# 2                          5977
# 3                             0
# 4                          5466
# ..                          ...
# 951                           0
# 952                           0
# 953                           0
# 954                           0
# 955                           0
#
# [956 rows x 65 columns]

# %%
# Сохранение результирующего DataFrame в Excel файл
result_file_path = "/kaggle/working/summed_volumes_by_id.xlsx"
result_volumes.to_excel(result_file_path, index=False)

# %%
# Разделение столбцов на провозную плату и объем перевозок
freight_columns = [col for col in result_volumes.columns if "Провозная плата" in col]
tonnage_columns = [col for col in result_volumes.columns if "Объем перевозок" in col]

# Сортировка столбцов по дате, извлекая из имени столбца информацию о дате
sorted_freight_columns = sorted(freight_columns, key=lambda x: pd.to_datetime(x.split()[0], format="%Y/%m"))
sorted_tonnage_columns = sorted(tonnage_columns, key=lambda x: pd.to_datetime(x.split()[0], format="%Y/%m"))

# Создание нового DataFrame с нужным порядком столбцов
sorted_columns = ['ID'] + sorted_freight_columns + sorted_tonnage_columns
volumes_sorted = result_volumes[sorted_columns]

# Сохранение результата в новый файл или использование отсортированных данных для анализа
volumes_sorted.to_excel("/kaggle/working/sorted_volumes_by_date.xlsx", index=False)

# Отображение первых строк для проверки
volumes_sorted.head()
# Out:
#     ID 2022/01 Провозная плата 2022/02 Провозная плата  \
# 0    9                       0                       0
# 1   25                 1833430                 1986327
# 2   33                 8391136                 9859024
# 3   86                       0                       0
# 4  115                 5091833                 6576660
#
#   2022/03 Провозная плата 2022/04 Провозная плата 2022/05 Провозная плата  \
# 0                       0                       0                       0
# 1                 2130880                 2474585                 2081455
# 2                 9205997                10782588                 9835553
# 3                       0                       0                       0
# 4                 6802046                 9907326                 7867965
#
#   2022/06 Провозная плата 2022/07 Провозная плата 2022/08 Провозная плата  \
# 0                       0                       0                       0
# 1                 3286550                 2863569                 2243274
# 2                18380073                17302701                13666447
# 3                       0                       0                       0
# 4                 5868940                 6983278                 7681607
#
#   2022/09 Провозная плата  ... 2023/11 Объем перевозок(тн)  \
# 0                  155364  ...                           0
# 1                 2352663  ...                        7284
# 2                 8084979  ...                        4079
# 3                       0  ...                           0
# 4                14858867  ...                        4960
#
#   2023/12 Объем перевозок(тн) 2024/01 Объем перевозок(тн)  \
# 0                           0                           0
# 1                        5675                        3224
# 2                        4169                        5229
# 3                           0                           0
# 4                        5935                        3210
#
#   2024/02 Объем перевозок(тн) 2024/03 Объем перевозок(тн)  \
# 0                           0                           0
# 1                        3760                        3800
# 2                        5021                        4727
# 3                           0                           0
# 4                        6911                        8270
#
#   2024/04 Объем перевозок(тн) 2024/05 Объем перевозок(тн)  \
# 0                           0                           0
# 1                        6296                        4441
# 2                        6330                        5274
# 3                           0                           0
# 4                       10131                        5789
#
#   2024/06 Объем перевозок(тн) 2024/07 Объем перевозок(тн)  \
# 0                           0                           0
# 1                        5530                        6841
# 2                        4919                        4634
# 3                           0                           0
# 4                        5877                        6604
#
#   2024/08 Объем перевозок(тн)
# 0                          50
# 1                        8015
# 2                        5329
# 3                           0
# 4                        4677
#
# [5 rows x 65 columns]

# %%
volumes_sorted.loc[:, 'Отток'] = (volumes_sorted.filter(like='Провозная плата').T.rolling(window=12).sum().T.min(axis=1) == 0) | \
                                 (volumes_sorted.filter(like='Объем перевозок(тн)').T.rolling(window=12).sum().T.min(axis=1) == 0)
print(volumes_sorted.columns)
# Out:
# Index(['ID', '2022/01 Провозная плата', '2022/02 Провозная плата',
#        '2022/03 Провозная плата', '2022/04 Провозная плата',
#        '2022/05 Провозная плата', '2022/06 Провозная плата',
#        '2022/07 Провозная плата', '2022/08 Провозная плата',
#        '2022/09 Провозная плата', '2022/10 Провозная плата',
#        '2022/11 Провозная плата', '2022/12 Провозная плата',
#        '2023/01 Провозная плата', '2023/02 Провозная плата',
#        '2023/03 Провозная плата', '2023/04 Провозная плата',
#        '2023/05 Провозная плата', '2023/06 Провозная плата',
#        '2023/07 Провозная плата', '2023/08 Провозная плата',
#        '2023/09 Провозная плата', '2023/10 Провозная плата',
#        '2023/11 Провозная плата', '2023/12 Провозная плата',
#        '2024/01 Провозная плата', '2024/02 Провозная плата',
#        '2024/03 Провозная плата', '2024/04 Провозная плата',
#        '2024/05 Провозная плата', '2024/06 Провозная плата',
#        '2024/07 Провозная плата', '2024/08 Провозная плата',
#        '2022/01 Объем перевозок(тн)', '2022/02 Объем перевозок(тн)',
#        '2022/03 Объем перевозок(тн)', '2022/04 Объем перевозок(тн)',
#        '2022/05 Объем перевозок(тн)', '2022/06 Объем перевозок(тн)',
#        '2022/07 Объем перевозок(тн)', '2022/08 Объем перевозок(тн)',
#        '2022/09 Объем перевозок(тн)', '2022/10 Объем перевозок(тн)',
#        '2022/11 Объем перевозок(тн)', '2022/12 Объем перевозок(тн)',
#        '2023/01 Объем перевозок(тн)', '2023/02 Объем перевозок(тн)',
#        '2023/03 Объем перевозок(тн)', '2023/04 Объем перевозок(тн)',
#        '2023/05 Объем перевозок(тн)', '2023/06 Объем перевозок(тн)',
#        '2023/07 Объем перевозок(тн)', '2023/08 Объем перевозок(тн)',
#        '2023/09 Объем перевозок(тн)', '2023/10 Объем перевозок(тн)',
#        '2023/11 Объем перевозок(тн)', '2023/12 Объем перевозок(тн)',
#        '2024/01 Объем перевозок(тн)', '2024/02 Объем перевозок(тн)',
#        '2024/03 Объем перевозок(тн)', '2024/04 Объем перевозок(тн)',
#        '2024/05 Объем перевозок(тн)', '2024/06 Объем перевозок(тн)',
#        '2024/07 Объем перевозок(тн)', '2024/08 Объем перевозок(тн)', 'Отток'],
#       dtype='object')
# /tmp/ipykernel_30/3797371200.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   volumes_sorted.loc[:, 'Отток'] = (volumes_sorted.filter(like='Провозная плата').T.rolling(window=12).sum().T.min(axis=1) == 0) | \

# %%
# !pip install keras-tuner
# Out:
# Requirement already satisfied: keras-tuner in /opt/conda/lib/python3.10/site-packages (1.4.7)
# Requirement already satisfied: keras in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (3.3.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (21.3)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (2.32.3)
# Requirement already satisfied: kt-legacy in /opt/conda/lib/python3.10/site-packages (from keras-tuner) (1.0.5)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (1.26.4)
# Requirement already satisfied: rich in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (13.7.1)
# Requirement already satisfied: namex in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (0.0.8)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (3.11.0)
# Requirement already satisfied: optree in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (0.11.0)
# Requirement already satisfied: ml-dtypes in /opt/conda/lib/python3.10/site-packages (from keras->keras-tuner) (0.3.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->keras-tuner) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->keras-tuner) (2024.8.30)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from optree->keras->keras-tuner) (4.12.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->keras-tuner) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/conda/lib/python3.10/site-packages (from rich->keras->keras-tuner) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/conda/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Создаем список месячных колонок для провозной платы и объема перевозок
freight_cols = volumes_sorted.filter(like='Провозная плата').columns
volume_cols = volumes_sorted.filter(like='Объем перевозок(тн)').columns

# Подготовка данных для LSTM
sequences = []
targets = []
client_ids = []  # Хранение ID клиентов
sequence_length = 12  # Окно для последовательностей (12 месяцев)

for _, row in volumes_sorted.iterrows():
    # Получаем значения провозной платы и объемов перевозок
    freight = row[freight_cols].values.astype('float32')
    volumes = row[volume_cols].values.astype('float32')
    
    # Объединяем данные в одну матрицу с двумя признаками на каждый месяц
    data = np.stack([freight, volumes], axis=1)
    
    # Создаем последовательности длиной sequence_length и целевой признак оттока
    if len(data) >= sequence_length:
        for i in range(len(data) - sequence_length + 1):
            sequences.append(data[i:i+sequence_length])
            targets.append(int(row['Отток']))
            client_ids.append(row['ID'])  # Сохраняем ID клиента для каждой последовательности

# Преобразуем в numpy массивы и указываем типы данных
X = np.array(sequences, dtype='float32')
y = np.array(targets, dtype='int32')
client_ids = np.array(client_ids)

# Разделение на обучающую (60%), валидационную (20%) и тестовую (20%) выборки
X_train_val, X_test, y_train_val, y_test, train_val_client_ids, test_client_ids = train_test_split(
    X, y, client_ids, test_size=0.2, random_state=42
)
X_train, X_val, y_train, y_val, train_client_ids, val_client_ids = train_test_split(
    X_train_val, y_train_val, train_val_client_ids, test_size=0.25, random_state=42
)  # 0.25 * 0.8 = 0.2

# Построение модели LSTM
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(sequence_length, 2)),
    Dropout(0.2),
    LSTM(32),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Выход для вероятности оттока
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Обучение модели на обучающей и валидационной выборках
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))

# Оценка модели на тестовой выборке
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("Отчет по LSTM модели на тестовой выборке:")
print(classification_report(y_test, y_pred))

# Получение вероятностей оттока на тестовой выборке
churn_probabilities = model.predict(X_test)

# Сопоставляем тестовые ID с вероятностями и добавляем данные из volumes_sorted
test_results = pd.DataFrame({
    'Client_ID': test_client_ids,
    'Churn_Probability': churn_probabilities.flatten()
})

# Объединение результатов с исходными данными volumes_sorted на основе Client_ID
merged_results = test_results.merge(volumes_sorted, left_on='Client_ID', right_on='ID')

# Удаление столбцов 'Отток' и дублирующегося 'ID', перемещение 'Churn_Probability' вправо
merged_results.drop(columns=['Отток', 'ID'], inplace=True)
merged_results['Churn_Probability'] = merged_results.pop('Churn_Probability')

# Сортировка по вероятности оттока
merged_results = merged_results.sort_values(by='Churn_Probability', ascending=False)

# Сохранение в Excel
output_path = "/kaggle/working/client_churn_probabilities.xlsx"
with pd.ExcelWriter(output_path) as writer:
    merged_results.to_excel(writer, index=False, sheet_name="Churn_Probabilities")

print("Результаты сохранены в файл client_churn_probabilities.xlsx")
# Out:
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 8s 15ms/step - accuracy: 0.8420 - loss: 0.3793 - val_accuracy: 0.8971 - val_loss: 0.2538
# Epoch 2/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8880 - loss: 0.2817 - val_accuracy: 0.8981 - val_loss: 0.2515
# Epoch 3/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8911 - loss: 0.2682 - val_accuracy: 0.8999 - val_loss: 0.2482
# Epoch 4/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8944 - loss: 0.2673 - val_accuracy: 0.8974 - val_loss: 0.2488
# Epoch 5/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8884 - loss: 0.2666 - val_accuracy: 0.8996 - val_loss: 0.2469
# Epoch 6/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8928 - loss: 0.2683 - val_accuracy: 0.8999 - val_loss: 0.2466
# Epoch 7/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 13ms/step - accuracy: 0.8889 - loss: 0.2703 - val_accuracy: 0.9006 - val_loss: 0.2468
# Epoch 8/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8908 - loss: 0.2648 - val_accuracy: 0.9014 - val_loss: 0.2480
# Epoch 9/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8929 - loss: 0.2612 - val_accuracy: 0.9006 - val_loss: 0.2497
# Epoch 10/10
# 377/377 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8923 - loss: 0.2691 - val_accuracy: 0.9004 - val_loss: 0.2469
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Отчет по LSTM модели на тестовой выборке:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      2093
#            1       0.88      0.89      0.89      1923
#
#     accuracy                           0.89      4016
#    macro avg       0.89      0.89      0.89      4016
# weighted avg       0.89      0.89      0.89      4016
#
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Результаты сохранены в файл client_churn_probabilities.xlsx

# %%
# Оценка модели на валидационной выборке
y_val_pred = (model.predict(X_val) > 0.5).astype("int32")
print("Отчет по LSTM модели на валидационной выборке:")
print(classification_report(y_val, y_val_pred))

# Оценка модели на тестовой выборке
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("Отчет по LSTM модели на тестовой выборке:")
print(classification_report(y_test, y_pred))

# Получение финального значения потерь на валидационной выборке
val_loss = history.history['val_loss'][-1]  # Потери на валидационной выборке после последней эпохи
print(f"Loss на валидационной выборке: {val_loss:.4f}")
# Out:
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Отчет по LSTM модели на валидационной выборке:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91      2147
#            1       0.90      0.89      0.89      1868
#
#     accuracy                           0.90      4015
#    macro avg       0.90      0.90      0.90      4015
# weighted avg       0.90      0.90      0.90      4015
#
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Отчет по LSTM модели на тестовой выборке:
#               precision    recall  f1-score   support
#
#            0       0.90      0.89      0.90      2093
#            1       0.88      0.89      0.89      1923
#
#     accuracy                           0.89      4016
#    macro avg       0.89      0.89      0.89      4016
# weighted avg       0.89      0.89      0.89      4016
#
# Loss на валидационной выборке: 0.2469

# %%
#предсказание на 3 месяца. Увеличено окно до 15 месяцев, чтобы модель могла лучше понимать 
#общие тренды. Эти изменения позволят модели адаптироваться к долгосрочному прогнозированию и учитывать признаки, указывающие на отток в течение более продолжительного периода.
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Создаем список месячных колонок для провозной платы и объема перевозок
freight_cols = volumes_sorted.filter(like='Провозная плата').columns
volume_cols = volumes_sorted.filter(like='Объем перевозок(тн)').columns

# Подготовка данных для LSTM с 15-месячным окном и 3-месячным периодом предсказания
sequence_length = 15  # Окно для последовательностей (15 месяцев)
prediction_period = 3  # Период предсказания на 3 месяца

sequences = []
targets = []
client_ids = []  # Хранение ID клиентов

for _, row in volumes_sorted.iterrows():
    # Получаем значения провозной платы и объемов перевозок
    freight = row[freight_cols].values.astype('float32')
    volumes = row[volume_cols].values.astype('float32')
    
    # Объединяем данные в одну матрицу с двумя признаками на каждый месяц
    data = np.stack([freight, volumes], axis=1)
    
    # Создаем последовательности длиной sequence_length и целевой признак оттока на 3 месяца вперед
    if len(data) >= sequence_length + prediction_period:
        for i in range(len(data) - sequence_length - prediction_period + 1):
            sequences.append(data[i:i+sequence_length])
            # Определение метки 'Отток': 1, если нет активности в следующие 3 месяца, иначе 0
            next_3_months = data[i+sequence_length:i+sequence_length+prediction_period]
            targets.append(int((next_3_months.sum() == 0).all()))  # 1, если все значения 0, иначе 0
            client_ids.append(row['ID'])  # Сохраняем ID клиента для каждой последовательности

# Преобразуем в numpy массивы и указываем типы данных
X = np.array(sequences, dtype='float32')
y = np.array(targets, dtype='int32')
client_ids = np.array(client_ids)

# Разделение на обучающую, валидационную и тестовую выборки
X_train_val, X_test, y_train_val, y_test, train_val_client_ids, test_client_ids = train_test_split(
    X, y, client_ids, test_size=0.2, random_state=42
)
X_train, X_val, y_train, y_val, train_client_ids, val_client_ids = train_test_split(
    X_train_val, y_train_val, train_val_client_ids, test_size=0.25, random_state=42
)

# Построение модели LSTM
model = Sequential([
    LSTM(64, return_sequences=True, input_shape=(sequence_length, 2)),
    Dropout(0.2),
    LSTM(32),
    Dropout(0.2),
    Dense(1, activation='sigmoid')  # Выход для вероятности оттока
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Обучение модели на обучающей и валидационной выборках
history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))

# Оценка модели на тестовой выборке
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("Отчет по LSTM модели на тестовой выборке:")
print(classification_report(y_test, y_pred))

# Получение вероятностей оттока на тестовой выборке
churn_probabilities = model.predict(X_test)

# Сопоставляем тестовые ID с вероятностями и добавляем данные из volumes_sorted
test_results = pd.DataFrame({
    'Client_ID': test_client_ids,
    'Churn_Probability': churn_probabilities.flatten()
})

# Объединение результатов с исходными данными volumes_sorted на основе Client_ID
merged_results = test_results.merge(volumes_sorted, left_on='Client_ID', right_on='ID')

# Удаление столбцов 'Отток' и дублирующегося 'ID', перемещение 'Churn_Probability' вправо
merged_results.drop(columns=['Отток', 'ID'], inplace=True)
merged_results['Churn_Probability'] = merged_results.pop('Churn_Probability')

# Сортировка по вероятности оттока
merged_results = merged_results.sort_values(by='Churn_Probability', ascending=False)

# Сохранение в Excel
output_path = "/kaggle/working/client_churn_probabilities_3_months.xlsx"
with pd.ExcelWriter(output_path) as writer:
    merged_results.to_excel(writer, index=False, sheet_name="Churn_Probabilities")

print("Результаты сохранены в файл client_churn_probabilities_3_months.xlsx")
# Out:
# Epoch 1/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step - accuracy: 0.8139 - loss: 0.4203 - val_accuracy: 0.8490 - val_loss: 0.3585
# Epoch 2/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8369 - loss: 0.3668 - val_accuracy: 0.8487 - val_loss: 0.3558
# Epoch 3/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8412 - loss: 0.3634 - val_accuracy: 0.8487 - val_loss: 0.3601
# Epoch 4/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8507 - loss: 0.3495 - val_accuracy: 0.8508 - val_loss: 0.3562
# Epoch 5/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8480 - loss: 0.3463 - val_accuracy: 0.8529 - val_loss: 0.3580
# Epoch 6/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8559 - loss: 0.3376 - val_accuracy: 0.8511 - val_loss: 0.3558
# Epoch 7/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8509 - loss: 0.3450 - val_accuracy: 0.8525 - val_loss: 0.3536
# Epoch 8/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8478 - loss: 0.3519 - val_accuracy: 0.8543 - val_loss: 0.3546
# Epoch 9/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8507 - loss: 0.3432 - val_accuracy: 0.8539 - val_loss: 0.3551
# Epoch 10/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8571 - loss: 0.3429 - val_accuracy: 0.8539 - val_loss: 0.3544
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
# Отчет по LSTM модели на тестовой выборке:
#               precision    recall  f1-score   support
#
#            0       0.91      0.83      0.87      1677
#            1       0.79      0.88      0.83      1191
#
#     accuracy                           0.85      2868
#    macro avg       0.85      0.85      0.85      2868
# weighted avg       0.86      0.85      0.85      2868
#
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Результаты сохранены в файл client_churn_probabilities_3_months.xlsx

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# Список месячных колонок для провозной платы и объема перевозок
freight_cols = volumes_sorted.filter(like='Провозная плата').columns
volume_cols = volumes_sorted.filter(like='Объем перевозок(тн)').columns

# Параметры анализа
sequence_length = 12  # Окно для последовательностей (12 месяцев)

# Перебор для прогнозирования на 1, 2, 3, 4, 5 и 6 месяцев
for prediction_period in range(1, 7):
    sequences = []
    targets = []
    client_ids = []  # Хранение ID клиентов

    for _, row in volumes_sorted.iterrows():
        # Получаем значения провозной платы и объемов перевозок
        freight = row[freight_cols].values.astype('float32')
        volumes = row[volume_cols].values.astype('float32')
        
        # Объединяем данные в матрицу с двумя признаками на каждый месяц
        data = np.stack([freight, volumes], axis=1)
        
        # Создаем последовательности длиной sequence_length и целевой признак оттока на "prediction_period" месяцев вперед
        if len(data) >= sequence_length + prediction_period:
            for i in range(len(data) - sequence_length - prediction_period + 1):
                sequences.append(data[i:i+sequence_length])
                
                # Определение метки 'Отток': 1, если нет активности в следующие "prediction_period" месяцев, иначе 0
                future_period = data[i+sequence_length:i+sequence_length+prediction_period]
                targets.append(int((future_period.sum() == 0).all()))  # 1, если все значения 0, иначе 0
                client_ids.append(row['ID'])  # Сохраняем ID клиента для каждой последовательности

    # Преобразуем в numpy массивы и указываем типы данных
    X = np.array(sequences, dtype='float32')
    y = np.array(targets, dtype='int32')
    client_ids = np.array(client_ids)

    # Разделение на обучающую, валидационную и тестовую выборки
    X_train_val, X_test, y_train_val, y_test, train_val_client_ids, test_client_ids = train_test_split(
        X, y, client_ids, test_size=0.2, random_state=42
    )
    X_train, X_val, y_train, y_val, train_client_ids, val_client_ids = train_test_split(
        X_train_val, y_train_val, train_val_client_ids, test_size=0.25, random_state=42
    )

    # Построение модели LSTM
    model = Sequential([
        LSTM(64, return_sequences=True, input_shape=(sequence_length, 2)),
        Dropout(0.2),
        LSTM(32),
        Dropout(0.2),
        Dense(1, activation='sigmoid')  # Выход для вероятности оттока
    ])

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Обучение модели на обучающей и валидационной выборках
    history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))

    # Оценка модели на тестовой выборке
    y_pred = (model.predict(X_test) > 0.5).astype("int32")
    print(f"\nОтчет по LSTM модели на тестовой выборке для периода предсказания {prediction_period} месяца(ев):")
    print(classification_report(y_test, y_pred))

    # Получение вероятностей оттока на тестовой выборке
    churn_probabilities = model.predict(X_test)

    # Сопоставляем тестовые ID с вероятностями и добавляем данные из volumes_sorted
    test_results = pd.DataFrame({
        'Client_ID': test_client_ids,
        'Churn_Probability': churn_probabilities.flatten()
    })

    # Объединение результатов с исходными данными volumes_sorted на основе Client_ID
    merged_results = test_results.merge(volumes_sorted, left_on='Client_ID', right_on='ID')

    # Удаление столбцов 'Отток' и дублирующегося 'ID', перемещение 'Churn_Probability' вправо
    merged_results.drop(columns=['Отток', 'ID'], inplace=True)
    merged_results['Churn_Probability'] = merged_results.pop('Churn_Probability')

    # Сортировка по вероятности оттока
    merged_results = merged_results.sort_values(by='Churn_Probability', ascending=False)

    # Сохранение в Excel
    output_path = f"/kaggle/working/client_churn_probabilities_{prediction_period}_months.xlsx"
    with pd.ExcelWriter(output_path) as writer:
        merged_results.to_excel(writer, index=False, sheet_name=f"Churn_Probabilities_{prediction_period}M")

    print(f"Результаты сохранены в файл client_churn_probabilities_{prediction_period}_months.xlsx")
# Out:
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 16ms/step - accuracy: 0.8421 - loss: 0.4018 - val_accuracy: 0.8661 - val_loss: 0.3286
# Epoch 2/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8601 - loss: 0.3374 - val_accuracy: 0.8677 - val_loss: 0.3248
# Epoch 3/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8677 - loss: 0.3313 - val_accuracy: 0.8682 - val_loss: 0.3247
# Epoch 4/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8695 - loss: 0.3307 - val_accuracy: 0.8666 - val_loss: 0.3255
# Epoch 5/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8695 - loss: 0.3260 - val_accuracy: 0.8672 - val_loss: 0.3241
# Epoch 6/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8706 - loss: 0.3180 - val_accuracy: 0.8695 - val_loss: 0.3234
# Epoch 7/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8709 - loss: 0.3202 - val_accuracy: 0.8656 - val_loss: 0.3245
# Epoch 8/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8695 - loss: 0.3281 - val_accuracy: 0.8653 - val_loss: 0.3235
# Epoch 9/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.8650 - loss: 0.3294 - val_accuracy: 0.8658 - val_loss: 0.3237
# Epoch 10/10
# 359/359 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8666 - loss: 0.3260 - val_accuracy: 0.8672 - val_loss: 0.3232
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Отчет по LSTM модели на тестовой выборке для периода предсказания 1 месяца(ев):
#               precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84      1780
#            1       0.86      0.88      0.87      2044
#
#     accuracy                           0.86      3824
#    macro avg       0.86      0.86      0.86      3824
# weighted avg       0.86      0.86      0.86      3824
#
# 120/120 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Результаты сохранены в файл client_churn_probabilities_1_months.xlsx
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.8296 - loss: 0.4222 - val_accuracy: 0.8580 - val_loss: 0.3395
# Epoch 2/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8595 - loss: 0.3487 - val_accuracy: 0.8599 - val_loss: 0.3373
# Epoch 3/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8488 - loss: 0.3688 - val_accuracy: 0.8602 - val_loss: 0.3336
# Epoch 4/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8663 - loss: 0.3389 - val_accuracy: 0.8585 - val_loss: 0.3359
# Epoch 5/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8565 - loss: 0.3509 - val_accuracy: 0.8552 - val_loss: 0.3382
# Epoch 6/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8588 - loss: 0.3510 - val_accuracy: 0.8541 - val_loss: 0.3413
# Epoch 7/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8591 - loss: 0.3479 - val_accuracy: 0.8566 - val_loss: 0.3397
# Epoch 8/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8595 - loss: 0.3507 - val_accuracy: 0.8582 - val_loss: 0.3358
# Epoch 9/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8568 - loss: 0.3573 - val_accuracy: 0.8547 - val_loss: 0.3383
# Epoch 10/10
# 341/341 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8589 - loss: 0.3467 - val_accuracy: 0.8566 - val_loss: 0.3358
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Отчет по LSTM модели на тестовой выборке для периода предсказания 2 месяца(ев):
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      1915
#            1       0.85      0.84      0.84      1718
#
#     accuracy                           0.85      3633
#    macro avg       0.85      0.85      0.85      3633
# weighted avg       0.85      0.85      0.85      3633
#
# 114/114 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Результаты сохранены в файл client_churn_probabilities_2_months.xlsx
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 9s 16ms/step - accuracy: 0.7959 - loss: 0.4455 - val_accuracy: 0.8361 - val_loss: 0.3780
# Epoch 2/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8434 - loss: 0.3712 - val_accuracy: 0.8379 - val_loss: 0.3667
# Epoch 3/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8458 - loss: 0.3621 - val_accuracy: 0.8463 - val_loss: 0.3665
# Epoch 4/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8465 - loss: 0.3633 - val_accuracy: 0.8457 - val_loss: 0.3652
# Epoch 5/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8496 - loss: 0.3620 - val_accuracy: 0.8469 - val_loss: 0.3659
# Epoch 6/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8529 - loss: 0.3605 - val_accuracy: 0.8457 - val_loss: 0.3657
# Epoch 7/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8406 - loss: 0.3720 - val_accuracy: 0.8463 - val_loss: 0.3656
# Epoch 8/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.8456 - loss: 0.3566 - val_accuracy: 0.8431 - val_loss: 0.3640
# Epoch 9/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8467 - loss: 0.3645 - val_accuracy: 0.8466 - val_loss: 0.3643
# Epoch 10/10
# 323/323 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8452 - loss: 0.3607 - val_accuracy: 0.8463 - val_loss: 0.3651
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Отчет по LSTM модели на тестовой выборке для периода предсказания 3 месяца(ев):
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      1942
#            1       0.79      0.89      0.83      1500
#
#     accuracy                           0.85      3442
#    macro avg       0.85      0.85      0.85      3442
# weighted avg       0.85      0.85      0.85      3442
#
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Результаты сохранены в файл client_churn_probabilities_3_months.xlsx
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.8009 - loss: 0.4475 - val_accuracy: 0.8290 - val_loss: 0.3687
# Epoch 2/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8324 - loss: 0.3779 - val_accuracy: 0.8416 - val_loss: 0.3616
# Epoch 3/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8370 - loss: 0.3798 - val_accuracy: 0.8410 - val_loss: 0.3708
# Epoch 4/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8357 - loss: 0.3727 - val_accuracy: 0.8404 - val_loss: 0.3609
# Epoch 5/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8353 - loss: 0.3759 - val_accuracy: 0.8397 - val_loss: 0.3615
# Epoch 6/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8418 - loss: 0.3710 - val_accuracy: 0.8404 - val_loss: 0.3603
# Epoch 7/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8339 - loss: 0.3788 - val_accuracy: 0.8394 - val_loss: 0.3594
# Epoch 8/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8423 - loss: 0.3670 - val_accuracy: 0.8391 - val_loss: 0.3600
# Epoch 9/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8403 - loss: 0.3683 - val_accuracy: 0.8416 - val_loss: 0.3610
# Epoch 10/10
# 305/305 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - accuracy: 0.8391 - loss: 0.3762 - val_accuracy: 0.8394 - val_loss: 0.3596
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step
#
# Отчет по LSTM модели на тестовой выборке для периода предсказания 4 месяца(ев):
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86      1960
#            1       0.76      0.86      0.80      1291
#
#     accuracy                           0.83      3251
#    macro avg       0.83      0.84      0.83      3251
# weighted avg       0.84      0.83      0.84      3251
#
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Результаты сохранены в файл client_churn_probabilities_4_months.xlsx
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.7786 - loss: 0.4617 - val_accuracy: 0.8333 - val_loss: 0.3757
# Epoch 2/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8189 - loss: 0.3958 - val_accuracy: 0.8356 - val_loss: 0.3624
# Epoch 3/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8253 - loss: 0.3855 - val_accuracy: 0.8365 - val_loss: 0.3622
# Epoch 4/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8213 - loss: 0.3871 - val_accuracy: 0.8352 - val_loss: 0.3640
# Epoch 5/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 17ms/step - accuracy: 0.8240 - loss: 0.3901 - val_accuracy: 0.8349 - val_loss: 0.3621
# Epoch 6/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8244 - loss: 0.3873 - val_accuracy: 0.8392 - val_loss: 0.3652
# Epoch 7/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8274 - loss: 0.3857 - val_accuracy: 0.8356 - val_loss: 0.3641
# Epoch 8/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8277 - loss: 0.3750 - val_accuracy: 0.8359 - val_loss: 0.3639
# Epoch 9/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.8367 - loss: 0.3758 - val_accuracy: 0.8369 - val_loss: 0.3672
# Epoch 10/10
# 287/287 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8228 - loss: 0.3899 - val_accuracy: 0.8356 - val_loss: 0.3618
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
# Отчет по LSTM модели на тестовой выборке для периода предсказания 5 месяца(ев):
#               precision    recall  f1-score   support
#
#            0       0.90      0.81      0.85      1944
#            1       0.71      0.84      0.77      1116
#
#     accuracy                           0.82      3060
#    macro avg       0.80      0.82      0.81      3060
# weighted avg       0.83      0.82      0.82      3060
#
# 96/96 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# Результаты сохранены в файл client_churn_probabilities_5_months.xlsx
# Epoch 1/10
# /opt/conda/lib/python3.10/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 8s 16ms/step - accuracy: 0.7969 - loss: 0.4370 - val_accuracy: 0.8075 - val_loss: 0.4096
# Epoch 2/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8188 - loss: 0.3890 - val_accuracy: 0.7950 - val_loss: 0.4142
# Epoch 3/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.8259 - loss: 0.3782 - val_accuracy: 0.8079 - val_loss: 0.4035
# Epoch 4/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8159 - loss: 0.3881 - val_accuracy: 0.8068 - val_loss: 0.4081
# Epoch 5/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8195 - loss: 0.3810 - val_accuracy: 0.8089 - val_loss: 0.4040
# Epoch 6/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8171 - loss: 0.3808 - val_accuracy: 0.8054 - val_loss: 0.4029
# Epoch 7/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8225 - loss: 0.3773 - val_accuracy: 0.8121 - val_loss: 0.4040
# Epoch 8/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8197 - loss: 0.3804 - val_accuracy: 0.8100 - val_loss: 0.4045
# Epoch 9/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.8188 - loss: 0.3843 - val_accuracy: 0.8086 - val_loss: 0.4023
# Epoch 10/10
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step - accuracy: 0.8175 - loss: 0.3814 - val_accuracy: 0.8107 - val_loss: 0.4030
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
#
# Отчет по LSTM модели на тестовой выборке для периода предсказания 6 месяца(ев):
#               precision    recall  f1-score   support
#
#            0       0.91      0.80      0.85      1909
#            1       0.68      0.84      0.75       959
#
#     accuracy                           0.81      2868
#    macro avg       0.79      0.82      0.80      2868
# weighted avg       0.83      0.81      0.82      2868
#
# 90/90 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# Результаты сохранены в файл client_churn_probabilities_6_months.xlsx

# %%
import pandas as pd

# Загрузка данных из файла Excel
df = pd.read_excel("/kaggle/input/da-rzhd/tatarstan.xls")

# Очистка столбца от пробелов и скрытых символов
df['ЕЛС действующий'] = df['ЕЛС действующий'].str.strip()

# Фильтрация строк, где столбец 'ЕЛС действующий' не пустой, и вывод уникальных ID
filtered_ids = df[df['ЕЛС действующий'].notna() & (df['ЕЛС действующий'] != '')]['ID'].unique()

# Печать всех уникальных ID
print(filtered_ids.tolist())
# Out:
# [6252, 6256, 6258, 6259, 6261, 6262, 6264, 6265, 6266, 6271, 6273, 6278, 6282, 6287, 6290, 6300, 6305, 6307, 6309, 6313, 6314, 6315, 6316, 6320, 6321, 6323, 6325, 6326, 6327, 6328, 6329, 6332, 6333, 6335, 6336, 6337, 6338, 6339, 6341, 6342, 6344, 6346, 6348, 6349, 6353, 6356, 6357, 6359, 6380, 6400, 6401, 247, 1023, 6411, 6412, 6413, 6414, 6436, 6448, 6449, 6496, 6497, 6508, 6509, 6515, 6577, 6597, 6631, 6639, 6665, 6673, 6677, 6679, 6687, 6694, 6701, 6730, 6764, 6765, 6783, 6788, 6798, 6809, 6813, 6815, 6826, 6828, 6831, 6833, 6834, 6837, 6846, 6853, 6856, 6861, 6865, 6867, 6870, 6872, 6875, 6876, 6885, 6888, 6890, 6896, 6897, 6903, 6909, 6912, 6913, 6914, 6916, 6917, 6921, 6927, 6928, 6938, 6945, 6947, 6955, 6956, 6957, 6961, 6966, 6969, 6971, 6975, 6979, 6980, 6985, 6988, 6994, 6996, 7000, 7004, 5272, 7015, 7016, 7024, 7030, 7033, 7037, 7042, 7043, 7052, 6645, 7057, 7059, 7070, 7071, 7072, 7077, 7082, 7087, 7089, 7092, 7094, 7096, 7099, 7101, 7102, 7111, 7115, 7116, 7117, 7119, 7122, 7123, 7125, 7128, 7133, 7139, 7140, 7141, 7143, 7144, 7146, 7149, 7151, 7154, 7155, 7156, 7157, 7158, 7162, 7164, 7168, 7169, 7177, 7179, 7184, 7185, 7186, 7188, 7191, 7193, 7205, 7206, 7207, 7209, 7210, 7211, 7214, 7215, 7221, 7222, 7225, 7228, 7242, 7243, 7244, 7246, 7247, 7252, 7254, 7256, 7262, 7263, 7267, 7268, 7276, 7278, 7279, 7282, 7283, 7284, 7288, 7295, 7296, 7298, 7300, 7301, 7308, 7310, 7311, 7318, 7339, 7341, 7342, 7346, 7347, 7351, 7363, 7364, 7368, 7370, 7375, 7378, 7380, 7381, 7387, 7390, 7392, 7393, 7397, 7401, 7406, 7413, 7414, 7416, 7417, 7418, 7436, 7437, 7442, 7443, 7444, 7447, 7449, 7450, 7455, 7457, 7458, 7468, 7472, 7480, 7481, 7482, 7486, 7489, 7490, 7491, 7492, 7496, 7499, 7501, 7508, 7515, 7518, 7519, 7520, 7522, 7523, 7525, 7529, 7536, 7538, 7546, 7547, 7551, 7564, 7568, 7569, 7570, 7571, 7575, 7581, 7582, 7584, 7586, 7587, 7592, 7602, 7605, 7609, 7611, 7615, 7624, 7628, 7640, 7650, 7653, 7655, 7656, 7657, 7660, 7663, 7665, 7668, 7669, 7678, 7679, 7680, 7687, 7697, 7708, 7713, 7714, 7718, 7722, 7728, 7731, 7732, 7744, 7745, 7746, 7747, 7753, 7761, 7763, 7764, 7765, 7771, 7775, 7785, 7787, 7795, 7798, 7799, 7804, 7813, 7815, 7820, 7829, 7832, 7835, 7838, 7841, 7846, 7847, 7852, 7856, 7862, 7879, 7880, 7887, 7896, 7905, 7912, 7913, 7918, 7926, 7927, 7928, 7930, 7933, 7936, 7938, 7940, 7942, 7944, 7945, 7955, 7956, 6248, 7960, 7961, 7968, 7973, 7978, 7983, 7985, 7988, 7990, 7991, 7995, 8001, 8002, 8003, 8010, 8023, 8025, 8026, 8030, 8034, 8045, 8048, 8051, 8052, 8054, 8055, 8059, 8062, 8065, 8068, 8076, 8090, 8094, 8096, 8098, 8102, 8105, 8108, 8112, 8115, 8123, 8126, 8127, 8128, 8129, 8130, 8131, 8134, 8140, 8141, 8143, 8151, 8152, 8158, 8161, 8163, 8174, 8177, 8178, 8188, 8191, 8192, 8200, 8203, 8209, 8211, 8213, 8216, 8228, 8229, 8232, 8237, 8240, 8243, 8245, 8246, 8248, 8250, 8252, 8256, 8258, 8260, 8266, 8272, 8282, 8285, 8287, 8291, 8310, 8312, 8375, 8385, 8386, 8397, 8402, 8409, 8423, 8425, 8434, 8441, 8452, 8455, 8464, 8471, 8496, 8498, 8500, 8567, 8582, 6246, 8634, 8637, 8654, 8680]
